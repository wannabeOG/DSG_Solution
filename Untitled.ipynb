# %%
import pandas as pd 
import numpy as np

# %%
training_set=pd.read_csv('mushroom_train.csv')
test_set=pd.read_csv('mushroom_test.csv')

# %%
Y_test=training_set['class']
X_test=training_set.drop('class',axis=1)

# %%
X_test[X_test.dtypes[(X_test.dtypes=="float64")|(X_test.dtypes=="int64")].index.values]
# Out:
#       radius  weight
# 0        215      38
# 1         94      43
# 2        244      37
# 3        286      82
# 4        110      36
# 5         66      23
# 6         11      43
# 7        207      25
# 8         60      50
# 9         84      47
# 10       385      34
# 11         3      43
# 12        59      23
# 13        57      36
# 14       151      64
# 15       264      23
# 16       183      60
# 17       315      40
# 18       298      23
# 19        99      26
# 20       782      38
# 21       262      23
# 22       129      23
# 23        55      23
# 24       115      27
# 25       186      23
# 26         7      50
# 27       417      46
# 28       226      32
# 29        59      36
# ...      ...     ...
# 5656      25      23
# 5657     178      24
# 5658     152      55
# 5659      39      23
# 5660       6      24
# 5661     425      47
# 5662      13      23
# 5663     404      23
# 5664      22      24
# 5665     178      45
# 5666     473      24
# ...

# %%
X_test.dtypes[(X_test.dtypes=='int64')|(X_test.dtypes=='float64')].index.values]
# Out:
# array(['radius', 'weight'], dtype=object)
